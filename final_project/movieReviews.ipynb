# %% [markdown]
# # Classifying Movie Reviews

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Load and Train Dataset

# %%
import keras
from keras.datasets import imdb

keras.__version__
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

train_data[0]
# Out:
# Using TensorFlow backend.
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %% [markdown]
# ### Load Labels

# %%
train_labels[0]
# Out:
# 1

# %% [markdown]
# ### Limit word index to 10,000

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# ### Vectorize Data

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# ### Vectorize Labels

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# ## Building our network

# %% [markdown]
# ### Implementing the Network

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From /Users/sarah/Documents/Calvin/Senior/Spring/CS_344/CS344/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Configure with optimizer and loss function

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Validating the approach

# %% [markdown]
# ### Create Validation set

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# ### Train model and monitor loss and accuracy

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# WARNING:tensorflow:From /Users/sarah/Documents/Calvin/Senior/Spring/CS_344/CS344/venv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 7s 481us/step - loss: 0.5084 - acc: 0.7813 - val_loss: 0.3797 - val_acc: 0.8684
# Epoch 2/20
# 15000/15000 [==============================] - 3s 232us/step - loss: 0.3004 - acc: 0.9047 - val_loss: 0.3004 - val_acc: 0.8897
# Epoch 3/20
# 15000/15000 [==============================] - 3s 186us/step - loss: 0.2179 - acc: 0.9285 - val_loss: 0.3086 - val_acc: 0.8711
# Epoch 4/20
# 15000/15000 [==============================] - 2s 164us/step - loss: 0.1750 - acc: 0.9437 - val_loss: 0.2840 - val_acc: 0.8832
# Epoch 5/20
# 15000/15000 [==============================] - 2s 162us/step - loss: 0.1427 - acc: 0.9543 - val_loss: 0.2841 - val_acc: 0.8872
# Epoch 6/20
# 15000/15000 [==============================] - 2s 159us/step - loss: 0.1150 - acc: 0.9650 - val_loss: 0.3165 - val_acc: 0.8772
# Epoch 7/20
# 15000/15000 [==============================] - 2s 159us/step - loss: 0.0980 - acc: 0.9705 - val_loss: 0.3127 - val_acc: 0.8845
# Epoch 8/20
# 15000/15000 [==============================] - 2s 158us/step - loss: 0.0807 - acc: 0.9764 - val_loss: 0.3859 - val_acc: 0.8649
# Epoch 9/20
# 15000/15000 [==============================] - 2s 164us/step - loss: 0.0661 - acc: 0.9821 - val_loss: 0.3635 - val_acc: 0.8782
# Epoch 10/20
# 15000/15000 [==============================] - 2s 157us/step - loss: 0.0562 - acc: 0.9851 - val_loss: 0.3842 - val_acc: 0.8794
# Epoch 11/20
# 15000/15000 [==============================] - 2s 162us/step - loss: 0.0437 - acc: 0.9896 - val_loss: 0.4151 - val_acc: 0.8783
# Epoch 12/20
# 15000/15000 [==============================] - 2s 161us/step - loss: 0.0380 - acc: 0.9920 - val_loss: 0.4538 - val_acc: 0.8684
# Epoch 13/20
# 15000/15000 [==============================] - 2s 165us/step - loss: 0.0300 - acc: 0.9926 - val_loss: 0.4700 - val_acc: 0.8725
# Epoch 14/20
# 15000/15000 [==============================] - 2s 163us/step - loss: 0.0247 - acc: 0.9945 - val_loss: 0.5025 - val_acc: 0.8725
# Epoch 15/20
# 15000/15000 [==============================] - 2s 147us/step - loss: 0.0180 - acc: 0.9977 - val_loss: 0.5314 - val_acc: 0.8707
# Epoch 16/20
# 15000/15000 [==============================] - 3s 170us/step - loss: 0.0185 - acc: 0.9960 - val_loss: 0.5642 - val_acc: 0.8695
# Epoch 17/20
# 15000/15000 [==============================] - 3s 178us/step - loss: 0.0100 - acc: 0.9994 - val_loss: 0.6308 - val_acc: 0.8616
# Epoch 18/20
# 15000/15000 [==============================] - 2s 148us/step - loss: 0.0135 - acc: 0.9969 - val_loss: 0.6365 - val_acc: 0.8676
# Epoch 19/20
# 15000/15000 [==============================] - 2s 146us/step - loss: 0.0059 - acc: 0.9997 - val_loss: 0.7218 - val_acc: 0.8576
# Epoch 20/20
# 15000/15000 [==============================] - 3s 175us/step - loss: 0.0062 - acc: 0.9994 - val_loss: 0.7034 - val_acc: 0.8663

# %% [markdown]
# ### Look at history

# %%
history_dict = history.history
history_dict.keys()
### Plot training and validation loss
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Plot training and validation accuracy

# %%
plt.clf()   # clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Train and test a new network from scratch

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)

results
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 5s 219us/step - loss: 0.4584 - acc: 0.8133
# Epoch 2/4
# 25000/25000 [==============================] - 3s 122us/step - loss: 0.2630 - acc: 0.9094
# Epoch 3/4
# 25000/25000 [==============================] - 3s 129us/step - loss: 0.2005 - acc: 0.9281
# Epoch 4/4
# 25000/25000 [==============================] - 3s 129us/step - loss: 0.1682 - acc: 0.9393
# 25000/25000 [==============================] - 7s 293us/step
# [0.29961957361221314, 0.88232]

# %% [markdown]
# ## Using a trained network to generate predictions on new data

# %%
model.predict(x_test)
# Out:
# array([[0.21131486],
#        [0.9995018 ],
#        [0.9329197 ],
#        ...,
#        [0.14550352],
#        [0.1029892 ],
#        [0.706477  ]], dtype=float32)
